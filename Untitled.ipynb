# %%
import pandas as pd
data = pd.read_excel('datacig.xlsx')
data
# Out:
#           Date     lncons   lnprice     lntax    lntipi  D1july09reg  \
# 0   2005-01-01  22.770554  0.620785 -4.605170  4.441474            0
# 1   2005-02-01  22.904891  0.589702 -4.605170  4.298645            0
# 2   2005-03-01  22.876975  0.621620 -4.605170  4.417635            0
# 3   2005-04-01  22.912580  0.620064 -4.605170  4.351567            0
# 4   2005-05-01  22.963752  0.605539 -4.605170  4.418841            0
# ..         ...        ...       ...       ...       ...          ...
# 117 2014-10-01  22.861446  1.086282 -1.673976  4.889597            1
# 118 2014-11-01  22.790900  1.081386 -1.673976  4.886583            1
# 119 2014-12-01  23.006065  1.084191 -1.673976  4.852811            1
# 120 2015-01-01  22.540911  1.070181 -1.673976  4.695925            1
# 121 2015-02-01  22.491954  1.087177 -1.673976  4.670958            1
#
#      D2jan10tax  D3oct11tax  D4jul12reg(total advertisement ban)  \
# 0             0           0                                    0
# ...

# %%
data.describe()
# Out:
#            lncons     lnprice       lntax      lntipi  D1july09reg  \
# count  122.000000  122.000000  122.000000  122.000000   122.000000
# mean    22.835848    0.936851   -2.410671    4.619720     0.557377
# std      0.148654    0.170514    0.664727    0.126495     0.498745
# min     22.428656    0.589702   -4.605170    4.298645     0.000000
# 25%     22.761239    0.786303   -2.659260    4.529907     0.000000
# 50%     22.857615    1.009797   -2.277892    4.620054     1.000000
# 75%     22.940217    1.087124   -1.931022    4.714920     1.000000
# max     23.158421    1.194820   -1.673976    4.889597     1.000000
#
#        D2jan10tax  D3oct11tax  D4jul12reg(total advertisement ban)  \
# count  122.000000  122.000000                           122.000000
# mean     0.508197    0.336066                             0.262295
# std      0.501994    0.474310                             0.441696
# min      0.000000    0.000000                             0.000000
# ...

# %%
plt.scatter(data.lntax, data.lnprice)
plt.xlabel("Tax Rate (lntax)")
plt.ylabel("Cigarette Price (lnprice)")
plt.title("Relationship between Tax and Price")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c909dc86bd13> in <module>
# ----> 1 plt.scatter(data.lntax, data.lnprice)
#       2 plt.xlabel("Tax Rate (lntax)")
#       3 plt.ylabel("Cigaratte Price (lnprice)")
#       4 plt.title("Relationship between Tax and Price")
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplt as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-22001349d527> in <module>
# ----> 1 import matplotlib.pyplt as plt
#
# ModuleNotFoundError: No module named 'matplotlib.pyplt'

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
from matplotlib import rcParams
sns.set_style("whitegrid")
sns.set_context("poster")

# %%
plt.scatter(data.lntax, data.lnprice)
plt.xlabel("Tax Rate (lntax)")
plt.ylabel("Cigarette Price (lnprice)")
plt.title("Relationship between Tax and Price")
# Out:
# Text(0.5, 1.0, 'Relationship between Tax and Price')

# %%
sns.regplot(y="lnprice", x="lntax", data=data, fit_reg = True)

# %%
plt.hist(np.log(data.lnprice))
plt.title("lnprice")
plt.xlabel("Price")
plt.ylabel("Frequencey")
plt.show()

# %%
plt.hist(np.log(data.lntax))
plt.title("lntax")
plt.xlabel("Tax")
plt.ylabel("Frequencey")
plt.show()
# Out:
# /Users/TC/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:853: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/TC/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6735: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /Users/TC/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py:6736: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-72d2f48ac9bc> in <module>
# ----> 1 plt.hist(np.log(data.lntax))
#       2 plt.title("lntax")
#       3 plt.xlabel("Tax")
#       4 plt.ylabel("Frequencey")
#       5 plt.show()
#
# ...

# %%
plt.hist(np(data.lnprice))
plt.title("lnprice")
plt.xlabel("Price")
plt.ylabel("Frequencey")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-27ce63fb477a> in <module>
# ----> 1 plt.hist(np(data.lnprice))
#       2 plt.title("lnprice")
#       3 plt.xlabel("Price")
#       4 plt.ylabel("Frequencey")
#       5 plt.show()
#
# TypeError: 'module' object is not callable

# %%
plt.hist((data.lnprice))
plt.title("lnprice")
plt.xlabel("Price")
plt.ylabel("Frequencey")
plt.show()

# %%
plt.hist((data.lntax))
plt.title("lntax")
plt.xlabel("Tax")
plt.ylabel("Frequencey")
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
m = ols('lnprice ~ lntax',data).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                lnprice   R-squared:                       0.727
# Model:                            OLS   Adj. R-squared:                  0.725
# Method:                 Least Squares   F-statistic:                     319.5
# Date:                Sun, 29 Mar 2020   Prob (F-statistic):           1.27e-35
# Time:                        18:35:28   Log-Likelihood:                 122.39
# No. Observations:                 122   AIC:                            -240.8
# Df Residuals:                     120   BIC:                            -235.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.4641      0.031     47.862      0.000       1.404       1.525
# ...

# %%
series = data('lnprice', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4e891b67c34a> in <module>
# ----> 1 series = data('lnprice', header=0, index_col=0, parse_dates=True, squeeze=True)
#       2 series.plot()
#       3 pyplot.show()
#
# TypeError: 'DataFrame' object is not callable

# %%
data.inprice.plot()
series.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-c313ee883f86> in <module>
# ----> 1 data.inprice.plot()
#       2 pyplot.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'inprice'

# %%
data.lnprice.plot()
series.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-64f1491d0e8a> in <module>
# ----> 1 data.inprice.plot()
#       2 series.plot()
#       3 pyplot.show()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'inprice'

# %%
data.lnprice.plot()
series.plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f9ab560150ea> in <module>
#       1 data.lnprice.plot()
# ----> 2 series.plot()
#       3 pyplot.show()
#
# NameError: name 'series' is not defined

# %%
series = data.lnprice, header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()
# Out:
#   File "<ipython-input-20-e80b5c44c8e6>", line 1
#     series = data.lnprice, header=0, index_col=0, parse_dates=True, squeeze=True)
#                                                                                 ^
# SyntaxError: invalid syntax

# %%
ts = pd.Series(np.random.randn(1000),
index=pd.date_range('2005-01-01', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
index=ts.index, columns=list('ABCD'))
df = df.cumsum()
plt.figure()
df.plot()

# %%
plt.figure()

# %%
df.diff().hist(color='k', alpha=0.5, bins=50)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1c198fa750>,
# ...
#       dtype=object)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
pi = math.pi
x_list = np.arange(-2*pi,2*pi,0.1)
y_list = [math.cos(x) for x in x_list]
fig = plt.figure(1)
plot = fig.add_subplot(111)
plt.plot(x_list,y_list)
plot.tick_params(axis='x', labelsize=14)
plt.grid()
plt.title('Change label axis font size in matplotlib')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
pi = math.pi
x_list = np.arange(-2*pi,2*pi,0.1)
y_list = [math.cos(x) for x in x_list]
fig = plt.figure(1)
plot = fig.add_subplot(111)
plt.plot(x_list,y_list)
plot.tick_params(axis='x', labelsize=10)
plt.grid()
plt.title('Change label axis font size in matplotlib')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
pi = math.pi
x_list = np.arange(-2*pi,2*pi,0.1)
y_list = [math.cos(x) for x in x_list]
fig = plt.figure(1)
plot = fig.add_subplot(111)
plt.plot(x_list,y_list)
plot.tick_params(axis='x', labelsize=14)
plot.tick_params(axis='y', labelsize=14)
plt.grid()
plt.title('Change label axis font size in matplotlib')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import math
pi = math.pi
x_list = np.arange(-2*pi,2*pi,0.1)
y_list = [math.cos(x) for x in x_list]
fig = plt.figure(1)
plot = fig.add_subplot(111)
plt.plot(x_list,y_list)
plot.tick_params(axis='x', labelsize=12)
plot.tick_params(axis='y', labelsize=12)
plt.grid()
plt.title('Change label axis font size in matplotlib')
plt.show()
