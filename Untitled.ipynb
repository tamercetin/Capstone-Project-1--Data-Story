# %%
import panda as pd 
excel_file = 'movies.xls'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-c1db50232123> in <module>
# ----> 1 import panda as pd
#       2 xl_file = pd.ExcelFile('C:/Users/TC/Desktop/Springboard Data Science Bootcamp/data_wrangling_json/Capstone-Project-1 - all_data-cig.xlsx')
#
# ModuleNotFoundError: No module named 'panda'
